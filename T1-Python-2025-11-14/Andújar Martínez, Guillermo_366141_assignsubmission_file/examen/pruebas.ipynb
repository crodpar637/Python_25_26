# %%
# %run ejer1.py
# Out:
# nombre:guille,salario base:1000
# nombre:fran,salario base:800
# nombre:alan, salario base: 1200, ventas realizadas: [100, 150]
# nombre:miguel, salario base: 900, ventas realizadas: [100, 150]
# nombre:guilem,salario base:1000
# nombre:miguel, salario base: 950, ventas realizadas: [100, 150]

# %%
# %run ejer2.py
# Out:
# Nombre de la tapa: a
# Precio de la tapa: 10
# Cantidad vendida: 10
# Nombre de la tapa: b
# Precio de la tapa: 20
# Cantidad vendida: 3
# Nombre de la tapa: c
# Precio de la tapa: 5
# Cantidad vendida: 50
# Nombre de la tapa: d
# Precio de la tapa: 50
# Cantidad vendida: 3
# [('a', 10.0, 10), ('b', 20.0, 3), ('c', 5.0, 50), ('d', 50.0, 3)]
# {'a': (100.0, 10.0, 'Baja'), 'b': (60.0, 6.0, 'Baja'), 'c': (250.0, 25.0, 'Alta'), 'd': (150.0, 15.0, 'Baja')}

# %%
# %run ejer3.py
# Out:
# diccionario de diccionarios: {'1': {'nombre': 'Ana García', 'telefono': '611223344', 'fecha': '2025-03-15', 'personas': '4', 'mesa': '5'}, '2': {'nombre': 'Luis Martínez', 'telefono': '622334455', 'fecha': '2025-03-15', 'personas': '2', 'mesa': '3'}, '3': {'nombre': 'Maria López', 'telefono': '633445566', 'fecha': '2025-03-15', 'personas': '6', 'mesa': '8'}, '4': {'nombre': 'Carlos Ruiz', 'telefono': '644556677', 'fecha': '2025-03-16', 'personas': '3', 'mesa': '4'}, '5': {'nombre': 'Laura Fernández', 'telefono': '655667788', 'fecha': '2025-11-14', 'personas': '5', 'mesa': '6'}, '6': {'nombre': 'Javier Morales', 'telefono': '666778899', 'fecha': '2025-11-14', 'personas': '2', 'mesa': '2'}, '7': {'nombre': 'Elena Sánchez', 'telefono': '677889900', 'fecha': '2025-11-14', 'personas': '8', 'mesa': '10'}, '8': {'nombre': 'Pablo Torres', 'telefono': '688990011', 'fecha': '2025-11-14', 'personas': '3', 'mesa': '1'}, '9': {'nombre': 'Carmen Díaz', 'telefono': '699100122', 'fecha': '2025-11-14
# ...

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 215.8 kB/s eta 0:00:00 0:00:01
# ...
