# %%
# %run ejercicio1.py
# Out:
# Nombre: jorge- Salario base: 13.4
# Nombre: pepe- Salario base: 10.4
# Nombre: jorge- Salario base: 13.4- Ventas: []- Salario total: 13.4
# Nombre: pepe- Salario base: 10.4- Ventas: []- Salario total: 10.4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Freitas Moray, Víctor Manuel_366145_assignsubmission_file/ejercicio1.py:79
#      76     print(f"{v1.__str()}")
#      78 if __name__=="__main__":
# ---> 79     main()
#
# File ~/work/T1-Python-2025-11-14/Freitas Moray, Víctor Manuel_366145_assignsubmission_file/ejercicio1.py:70, in main()
#      67 print(f"{v1.__str__()}")
#      68 print(f"{v2.__str__()}")
# ---> 70 e1.nombre="jon"
#      71 print(f"{e1}")
#      73 print(f"{v1.agregar_venta(1.9)}")
#
# File ~/work/T1-Python-2025-11-14/Freitas Moray, Víctor Manuel_366145_assignsubmission_file/ejercicio1.py:21, in Empleado.nombre(self, valor)
# ...
