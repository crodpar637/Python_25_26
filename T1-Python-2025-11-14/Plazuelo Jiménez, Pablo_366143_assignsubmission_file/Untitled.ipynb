# %%
# %run ejercicio1.py
# Out:
# Nombre: Paco - Salario base: 200
# Nombre: Juan - Salario base: 230 - Ventas: [50, 50] - Salario total: 240.0
# Nombre: Paco - Salario base: 215
# Nombre: Juan - Salario base: 250 - Ventas: [50, 50, 20, 40] - Salario total: 266.0

# %%
# %run ejercicio2.py
# Out:
# Introduce datos de 4 tapas típicas Sevillanas:
# Introduce los datos de la tapa 1
# Introduce el nombre de la tapa:  a
# Introduce el precio unitario de la tapa:  10
# Introduce la cantidad vendida de la tapa:  20
# Introduce los datos de la tapa 2
# Introduce el nombre de la tapa:  1
# Introduce el precio unitario de la tapa:  1
# Introduce la cantidad vendida de la tapa:  1
# Introduce los datos de la tapa 3
# Introduce el nombre de la tapa:  3
# Introduce el precio unitario de la tapa:  3
# Introduce la cantidad vendida de la tapa:  3
# Introduce los datos de la tapa 4
# Introduce el nombre de la tapa:  4
# Introduce el precio unitario de la tapa:  4
# Introduce la cantidad vendida de la tapa:  4
# {'a': (200.0, 20.0, 'Media'), '1': (1.0, 0.1, 'Baja'), '3': (9.0, 0.9, 'Baja'), '4': (16.0, 1.6, 'Baja')}
# ([], 5.65, 'a')

# %%
# %run ejercicio3.py
# Out:
# [{'id': '1', 'nombre': 'Ana García', 'telefono': '611223344', 'fecha': '2025-03-15', 'personas': '4', 'mesa': '5'}, {'id': '2', 'nombre': 'Luis Martínez', 'telefono': '622334455', 'fecha': '2025-03-15', 'personas': '2', 'mesa': '3'}, {'id': '3', 'nombre': 'Maria López', 'telefono': '633445566', 'fecha': '2025-03-15', 'personas': '6', 'mesa': '8'}, {'id': '4', 'nombre': 'Carlos Ruiz', 'telefono': '644556677', 'fecha': '2025-03-16', 'personas': '3', 'mesa': '4'}, {'id': '5', 'nombre': 'Laura Fernández', 'telefono': '655667788', 'fecha': '2025-11-14', 'personas': '5', 'mesa': '6'}, {'id': '6', 'nombre': 'Javier Morales', 'telefono': '666778899', 'fecha': '2025-11-14', 'personas': '2', 'mesa': '2'}, {'id': '7', 'nombre': 'Elena Sánchez', 'telefono': '677889900', 'fecha': '2025-11-14', 'personas': '8', 'mesa': '10'}, {'id': '8', 'nombre': 'Pablo Torres', 'telefono': '688990011', 'fecha': '2025-11-14', 'personas': '3', 'mesa': '1'}, {'id': '9', 'nombre': 'Carmen Díaz', 'telefono': '6991001
# ...
