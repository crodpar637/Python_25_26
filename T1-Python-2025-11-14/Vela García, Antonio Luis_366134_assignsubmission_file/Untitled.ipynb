# %%
# %run ej1.py
# Out:
# Nombre: Antonio - Salario Base:<bound method Empleado.calcular_salario of <__main__.Empleado object at 0x7f82e6f32210>>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Vela García, Antonio Luis_366134_assignsubmission_file/ej1.py:42
#      40 empleado = Empleado("Antonio", 3000)
#      41 print(empleado)
# ---> 42 vendedor = Vendedor("Jorge",2000,list(("coche","piso","garaje")))
#      43 print(vendedor)
#
# File ~/work/T1-Python-2025-11-14/Vela García, Antonio Luis_366134_assignsubmission_file/ej1.py:29, in Vendedor.__init__(self, nombre, salario_base, ventas_realizadas)
#      27 def __init__(self,nombre,salario_base,ventas_realizadas):
#      28     super().__init__(nombre,salario_base)
# ---> 29     this.ventas_realizadas = list(ventas_realizadas)
#
# NameError: name 'this' is not defined

# %%
# %run ej3.py
# Out:
# Conexion SQL realizada
