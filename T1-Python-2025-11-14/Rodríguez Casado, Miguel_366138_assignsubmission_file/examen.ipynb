# %%
# %run ejercicio1
# Out:
# Nombre: Miguel - Salario base: 100.0
# Nombre: Sergio - Salario base: 1000.0
# Nombre: Sergio - Salario base: 1000.0

# %%
# %run ejercicio2
# Out:
# Nombre de la tapa:  a
# Precio unitario:  10
# Unidades vendidas:  10
# Nombre de la tapa:  b
# Precio unitario:  20
# Unidades vendidas:  20
# Nombre de la tapa:  c
# Precio unitario:  30
# Unidades vendidas:  30
# Nombre de la tapa:  d
# Precio unitario:  40
# Unidades vendidas:  40
# [('a', 10.0, 10), ('b', 20.0, 20), ('c', 30.0, 30), ('d', 40.0, 40)]
# {'a': (100.0, 10.0, 'Baja'), 'b': (400.0, 40.0, 'Media'), 'c': (900.0, 90.0, 'Alta'), 'd': (1600.0, 160.0, 'Alta')}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Rodríguez Casado, Miguel_366138_assignsubmission_file/ejercicio2.py:48
#      45     rendimiento = analizar_rendimineto_tapas(diccionario)
#      46     print(rendimiento)
# ---> 48 main()
#
# File ~/work/T1-Python-2025-11-14/Rodríguez Casado, Miguel_366138_assignsubmission_file/ejercicio2.py:45, in main()
# ...

# %%
# %run ejercicio3
# Out:
# {'1': {'nombre': 'Ana García', 'telefono': '611223344', 'fecha': '2025-03-15', 'personas': '4', 'mesa': '5'}, '2': {'nombre': 'Luis Martínez', 'telefono': '622334455', 'fecha': '2025-03-15', 'personas': '2', 'mesa': '3'}, '3': {'nombre': 'Maria López', 'telefono': '633445566', 'fecha': '2025-03-15', 'personas': '6', 'mesa': '8'}, '4': {'nombre': 'Carlos Ruiz', 'telefono': '644556677', 'fecha': '2025-03-16', 'personas': '3', 'mesa': '4'}, '5': {'nombre': 'Laura Fernández', 'telefono': '655667788', 'fecha': '2025-11-14', 'personas': '5', 'mesa': '6'}, '6': {'nombre': 'Javier Morales', 'telefono': '666778899', 'fecha': '2025-11-14', 'personas': '2', 'mesa': '2'}, '7': {'nombre': 'Elena Sánchez', 'telefono': '677889900', 'fecha': '2025-11-14', 'personas': '8', 'mesa': '10'}, '8': {'nombre': 'Pablo Torres', 'telefono': '688990011', 'fecha': '2025-11-14', 'personas': '3', 'mesa': '1'}, '9': {'nombre': 'Carmen Díaz', 'telefono': '699100122', 'fecha': '2025-11-14', 'personas': '4', 'mesa': '
# ...
