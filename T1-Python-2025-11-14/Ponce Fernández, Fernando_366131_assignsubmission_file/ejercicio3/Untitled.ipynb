# %%
# %run ejercicio2.py
# Out:
# Nombre de la tapa a
# Dime el precio unitario 10
# Dime la cantidad 10
# Nombre de la tapa b
# Dime el precio unitario 20
# Dime la cantidad 20
# Nombre de la tapa c
# Dime el precio unitario 30
# Dime la cantidad 30
# Nombre de la tapa d
# Dime el precio unitario 40
# Dime la cantidad 40
# [('d', 40.0, 40)]
# {'d': (1600.0, 1040.0, 'Alta')}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Ponce Fernández, Fernando_366131_assignsubmission_file/ejercicio3/ejercicio2.py:52
#      49     print(analizar_rendimiento_tapas(dic))
#      51 if __name__ == "__main__":
# ---> 52     main()
#
# File ~/work/T1-Python-2025-11-14/Ponce Fernández, Fernando_366131_assignsubmission_file/ejercicio3/ejercicio2.py:49, in main()
#      46 dic = calcular_estadisticas_tapa(datos)
#      47 print(dic)
# ---> 49 print(analizar_rendimiento_tapas(dic))
#
# ...
