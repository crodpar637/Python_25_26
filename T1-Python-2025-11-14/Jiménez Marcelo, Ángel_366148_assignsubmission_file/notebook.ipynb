# %%
# %run ejercicio1.py
# Out:
# Nombre: Javi - Salario base: 1500
# Nombre: Carlos - Salario base: 2000
# Nombre: Inma - Salario base: 1700 - Ventas: [10, 60, 30]Salario total: 1710.0
# Nombre: Marina - Salario base: 1900 - Ventas: [100, 150, 50]Salario total: 1930.0
# Nombre: Inma - Salario base: 1700 - Ventas: [10, 60, 30, 100]Salario total: 1720.0

# %%
# %run ejercicio2.py
# Out:
# Nombre de la tapa serranito
# Precio por unidad 3.5
# Cantidad vendida 25
# Nombre de la tapa solomillo
# Precio por unidad 4.2
# Cantidad vendida 18
# Nombre de la tapa montadito
# Precio por unidad 2.8
# Cantidad vendida 32
# Nombre de la tapa lentejas
# Precio por unidad 3.0
# Cantidad vendida 21
# [('serranito', 3.5, 25), ('solomillo', 4.2, 18), ('montadito', 2.8, 32), ('lentejas', 3.0, 21)]
# {'serranito': (87.5, 8.75, 'Media'), 'solomillo': (75.60000000000001, 7.560000000000001, 'Media'), 'montadito': (89.6, 8.959999999999999, 'Alta'), 'lentejas': (63.0, 6.300000000000001, 'Media')}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/ejercicio2.py:38
#      36 b = calcular_estadisticas_tapas(a)
#      37 print(b)
# ---> 38 print(analizar_rendimiento_tapas(b))
#
# File ~/ejercicio2.py:29, in analizar_rendimiento_tapas(dic_estadisticas)
# ...
