# %%
# %run Ejercicio1_POO.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Rincón Maya, Carlos_366140_assignsubmission_file/Ejercicio1_POO.py:64
#      61 v1 = Vendedor('José',1000,[150,300,220])
#      62 v2 = Vendedor('Pepa',1000,[175, 240, 190])
# ---> 64 print(e1)
#      65 print(e2)
#      66 print(v1)
#
# File ~/work/T1-Python-2025-11-14/Rincón Maya, Carlos_366140_assignsubmission_file/Ejercicio1_POO.py:28, in Empleado.__str__(self)
#      27 def __str__(self):
# ---> 28     return "Nombre: " + self.__nombre + " - Salario base: " + self.__salario_base
#
# TypeError: can only concatenate str (not "int") to str

# %%
# %run Ejercicio2_DatosFOS.py
# Out:
# Dime el nombre de la tapa a
# Dime el precio de cada unidad 10
# Dime la cantidad vendida 10
# Dime el nombre de la tapa b
# Dime el precio de cada unidad 20
# Dime la cantidad vendida 20
# Dime el nombre de la tapa v
# Dime el precio de cada unidad 30
# Dime la cantidad vendida 30
# Dime el nombre de la tapa d
# Dime el precio de cada unidad 40
# Dime la cantidad vendida 40
# [('a', 10.0, 10), ('b', 20.0, 20), ('v', 30.0, 30), ('d', 40.0, 40)]
# {'a': (100.0, 10.0, 'Baja'), 'b': (400.0, 40.0, 'Media'), 'v': (900.0, 90.0, 'Alta'), 'd': (1600.0, 160.0, 'Alta')}
# ([('v', (900.0, 90.0, 'Alta')), ('d', (1600.0, 160.0, 'Alta'))], 'd')

# %%
# %run Ejercicio3_CSV_BBDD.py
# Out:
# {'1': {'Nombre': 'Ana García', 'Teléfono': '611223344', 'Fecha': '2025-03-15', 'Personas': 4, 'Mesa': 5}, '2': {'Nombre': 'Luis Martínez', 'Teléfono': '622334455', 'Fecha': '2025-03-15', 'Personas': 2, 'Mesa': 3}, '3': {'Nombre': 'Maria López', 'Teléfono': '633445566', 'Fecha': '2025-03-15', 'Personas': 6, 'Mesa': 8}, '4': {'Nombre': 'Carlos Ruiz', 'Teléfono': '644556677', 'Fecha': '2025-03-16', 'Personas': 3, 'Mesa': 4}, '5': {'Nombre': 'Laura Fernández', 'Teléfono': '655667788', 'Fecha': '2025-11-14', 'Personas': 5, 'Mesa': 6}, '6': {'Nombre': 'Javier Morales', 'Teléfono': '666778899', 'Fecha': '2025-11-14', 'Personas': 2, 'Mesa': 2}, '7': {'Nombre': 'Elena Sánchez', 'Teléfono': '677889900', 'Fecha': '2025-11-14', 'Personas': 8, 'Mesa': 10}, '8': {'Nombre': 'Pablo Torres', 'Teléfono': '688990011', 'Fecha': '2025-11-14', 'Personas': 3, 'Mesa': 1}, '9': {'Nombre': 'Carmen Díaz', 'Teléfono': '699100122', 'Fecha': '2025-11-14', 'Personas': 4, 'Mesa': 7}, '10': {'Nombre': 'Antonio Navar
# ...

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.8 MB/s eta 0:00:00
# ...
