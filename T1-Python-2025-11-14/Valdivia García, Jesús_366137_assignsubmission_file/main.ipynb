# %%
# %run Ejercicio1.py
# Out:
# Nombre: Jesus, Salario base: 1000
# Nombre: Manuel, Salario base: 2000
# Nombre: Jesus, Salario base: 850.0
# Nombre: Manuel, Salario base: 2000
# Nombre: Iker, Salario base: 1000, Ventas: [100, 200, 200], Salario total: 1050.0
# Nombre: Herme, Salario base: 250, Ventas: [200, 350, 500], Salario total: 355.0
# Nombre: Iker, Salario base: 1000, Ventas: [100, 200, 200, 50, 1200], Salario total: 1175.0
# Nombre: Herme, Salario base: 250, Ventas: [200, 350, 500], Salario total: 355.0

# %%
# %run Ejercicio3.py
# Out:
# [('1', 'Ana García', '611223344', '2025-03-15', '4'), ('2', 'Luis Martínez', '622334455', '2025-03-15', '2'), ('3', 'Maria López', '633445566', '2025-03-15', '6'), ('4', 'Carlos Ruiz', '644556677', '2025-03-16', '3'), ('5', 'Laura Fernández', '655667788', '2025-11-14', '5'), ('6', 'Javier Morales', '666778899', '2025-11-14', '2'), ('7', 'Elena Sánchez', '677889900', '2025-11-14', '8'), ('8', 'Pablo Torres', '688990011', '2025-11-14', '3'), ('9', 'Carmen Díaz', '699100122', '2025-11-14', '4'), ('10', 'Antonio Navarro', '600111222', '2025-03-18', '2'), ('11', 'Sara Ramos', '611222333', '2025-03-19', '6'), ('12', 'David Ortega', '622333444', '2025-03-19', '5'), ('13', 'Isabel Romero', '633444555', '2025-03-19', '3'), ('14', 'Francisco Vega', '644555666', '2025-03-20', '2'), ('15', 'Patricia Castro', '655666777', '2025-03-20', '7'), ('16', 'Raúl Herrera', '666777888', '2025-03-20', '4'), ('17', 'Sonia León', '677888999', '2025-03-21', '5'), ('18', 'Manuel Gil', '688999000', '2025-03-21',
# ...

# %%
# %run Ejercicio2.py
# Out:
# {'Serranito': ('87.5', '8.75', 'Media'), 'Solimillo al Whisky': ('75.60000000000001', '7.560000000000001', 'Media'), 'Montadito de pringá': ('89.6', '8.959999999999999', 'Alta'), 'Espinacas con garbanzos': ('63.0', '6.300000000000001', 'Media')}
# [[('Montadito de pringá', ('89.6', '8.959999999999999', 'Alta'))], 'Montadito de pringá']
