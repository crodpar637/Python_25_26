# %%
# %run p1.py
# Out:
# Nombre: Jacinto - Salario base: 1500
# 1200.0
# Nombre: Pepe - Salario base: 1500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p1.py:64
#      60     print(vendedor.__str__())
#      61     # vendedor.salario_base = 2300
#      62     #
# ---> 64 main()
#
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p1.py:60, in main()
#      57 print(empleado.__str__())
#      59 vendedor = Vendedor("Carlos", 2000, [150,200,80])
# ---> 60 print(vendedor.__str__())
#
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p1.py:49, in Vendedor.__str__(self)
#      48 def __str__(self):
# ...

# %%
# %run p2.py
# Out:
# Nombre de la tapa:  a
# Precio unitario:  10
# Cantidad individual:  10
# Nombre de la tapa:  b
# Precio unitario:  5
# Cantidad individual:  5
# Nombre de la tapa:  c
# Precio unitario:  4
# Cantidad individual:  4
# Nombre de la tapa:  d
# Precio unitario:  9
# Cantidad individual:  8
# [('a', 10.0, 10), ('b', 5.0, 5), ('c', 4.0, 4), ('d', 9.0, 8)]
# {'Serranito': (87.5, 8.75, 'Media'), 'Solomillo al whisky': (75.60000000000001, 7.560000000000001, 'Media'), 'Montadito de pringa': (89.6, 8.96, 'Baja'), 'Espinacas con garbanzos': (63.0, 6.3, 'Media')}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p2.py:60
#      50     lista_ventas = [
#      51         {"nombre_tapa" : "Serranito", "precio_unitario" : 3.5, "cantidad_individual" : 25},
# ...

# %%
# %run p3.py
# Out:
# {'1': (False, False, False, False, False)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p3.py:40
#      38     insertar_reservas_bbdd("reservas.csv")
#      39     conn.close()
# ---> 40 main()
#
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p3.py:38, in main()
#      33 def main():
#      35     print(cargar_reservas_desde_csv())
# ---> 38     insertar_reservas_bbdd("reservas.csv")
#      39     conn.close()
#
# File ~/work/T1-Python-2025-11-14/Bonilla Varo, Francisco Javier_366147_assignsubmission_file/Examen/Examen/p3.py:15, in insertar_reservas_bbdd(reservas)
#      14 def insertar_reservas_bbdd(reservas):
# ---> 15     cursor = db_conn.cursor()
#      16     # Realizamos el insert en las filas
# ...
