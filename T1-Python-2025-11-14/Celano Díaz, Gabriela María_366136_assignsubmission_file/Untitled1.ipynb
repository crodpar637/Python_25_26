# %%
# %run ejercicio1.py
# Out:
# Nombre: Jose -Salario Base: 10000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Celano Díaz, Gabriela María_366136_assignsubmission_file/ejercicio1.py:69
#      67 vendedor = Vendedor("David",1000,ventas_vendedor)
#      68 print(empleado)
# ---> 69 print(vendedor)
#      70 #modificar un atributo utilizando setters:
#      71 empleado.nombre = "Ana"
#
# File ~/work/T1-Python-2025-11-14/Celano Díaz, Gabriela María_366136_assignsubmission_file/ejercicio1.py:60, in Vendedor.__str__(self)
#      59 def __str__(self):
# ---> 60     return super().__str__() + f" Ventas: {total_ventas} - Salario total: {salario_total}"
#
# NameError: name 'total_ventas' is not defined
