# %%
# %run Ejercicio1
# Out:
# Nombre: Juan - Salario base: 1000
# Nombre: Julia - Salario base: 1250
# Nombre: Juana - Salario base: 1500 - Ventas: [123, 321] - Salario total: 1650.0
# Nombre: Carlos - Salario base: 2000 - Ventas: [456, 654] - Salario total: 2200.0
# Nombre: Juan - Salario base: 1100
# Nombre: Julia Rodriguez - Salario base: 1250
# Nombre: Juana - Salario base: 1200 - Ventas: [123, 321, 100, 11] - Salario total: 1320.0
# Nombre: Carlos Rodriguez - Salario base: 2000 - Ventas: [456, 654, 200, 22] - Salario total: 2200.0

# %%
# %run Ejercicio2
# Out:
# Nombre de la tapa:  serranito
# Precio de la tapa:  10
# Cantidad de ventas de la tapa:  5
# Nombre de la tapa:  flamenquin
# Precio de la tapa:  3
# Cantidad de ventas de la tapa:  22
# Nombre de la tapa:  patatas bravas
# Precio de la tapa:  2
# Cantidad de ventas de la tapa:  34
# Nombre de la tapa:  gazpacho
# Precio de la tapa:  5
# Cantidad de ventas de la tapa:  2
# [('serranito', 10.0, 5), ('flamenquin', 3.0, 22), ('patatas bravas', 2.0, 34), ('gazpacho', 5.0, 2)]
# {'serranito': (50.0, 5.0, 'Baja'), 'flamenquin': (66.0, 6.6000000000000005, 'Media'), 'patatas bravas': (68.0, 6.800000000000001, 'Alta'), 'gazpacho': (10.0, 1.0, 'Baja')}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/work/T1-Python-2025-11-14/Coronel Ortiz, Javier_366132_assignsubmission_file/examenJavierCoronelOrtiz_14_11_2025/examenJavierCoronelOrtiz_14_11_2025/Ejercicio2.py:42
# ...
